# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, LabelEncoder

# %%
data = {
    'Age': [25, 45, 35, 50, 23],
    'Salaire': [40000, 80000, 60000, 120000, 38000],
    'Ville': ['Paris', 'Lyon', 'Paris', 'Marseille', 'Lyon'],
    'Achat': ['Non', 'Oui', 'Oui', 'Oui', 'Non']
}
df = pd.DataFrame(data)
print("Dataset Original :")
print(df)
# Out:
# Dataset Original :
#    Age  Salaire      Ville Achat
# 0   25    40000      Paris   Non
# 1   45    80000       Lyon   Oui
# 2   35    60000      Paris   Oui
# 3   50   120000  Marseille   Oui
# 4   23    38000       Lyon   Non

# %%
le = LabelEncoder()
df['Achat'] = le.fit_transform(df['Achat'])

# %%
df_encoded = pd.get_dummies(df, columns=['Ville'], prefix='Ville')

print("\nAprès Encodage (Label + One-Hot) :")
print(df_encoded)
# Out:
# Après Encodage (Label + One-Hot) :
#    Age  Salaire  Achat  Ville_Lyon  Ville_Marseille  Ville_Paris
# 0   25    40000      0       False            False         True
# 1   45    80000      1        True            False        False
# 2   35    60000      1       False            False         True
# 3   50   120000      1       False             True        False
# 4   23    38000      0        True            False        False

# %%
scaler_std = StandardScaler()
df_std = df_encoded.copy()
df_std[['Age', 'Salaire']] = scaler_std.fit_transform(df_encoded[['Age', 'Salaire']])

print("\nAprès Standardisation (Z-score) :")
print(df_std.head(2))
# Out:
# Après Standardisation (Z-score) :
#         Age   Salaire  Achat  Ville_Lyon  Ville_Marseille  Ville_Paris
# 0 -0.995228 -0.910420      0       False            False         True
# 1  0.882561  0.409029      1        True            False        False

# %%
scaler_minmax = MinMaxScaler()
df_minmax = df_encoded.copy()
df_minmax[['Age', 'Salaire']] = scaler_minmax.fit_transform(df_encoded[['Age', 'Salaire']])

print("\nAprès Normalisation Min-Max :")
print(df_minmax.head(2))
# Out:
# Après Normalisation Min-Max :
#         Age   Salaire  Achat  Ville_Lyon  Ville_Marseille  Ville_Paris
# 0  0.074074  0.024390      0       False            False         True
# 1  0.814815  0.512195      1        True            False        False
